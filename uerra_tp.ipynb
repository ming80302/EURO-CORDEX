# %%
import xarray as xr

# %%
flnm = '/glade/scratch/mingge/UERRA/prec_201901.grib'
ds = xr.load_dataset(flnm, engine="cfgrib",  backend_kwargs={'indexpath' :''}) 
ds.tp.plot()
